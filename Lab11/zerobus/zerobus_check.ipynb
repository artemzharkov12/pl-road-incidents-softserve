# %%
# %sql
SELECT * 
FROM dbr_dev.artemzharkov10_bronze.bronze_streaming_road_accidents
LIMIT 10

# %%
# %sql
SELECT 
    COUNT(*) AS total_rows,
    COUNT(DISTINCT json_payload) AS unique_payloads
FROM dbr_dev.artemzharkov10_bronze.bronze_streaming_road_accidents;
