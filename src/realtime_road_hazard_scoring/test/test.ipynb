# %%
df = spark.table("dbr_dev.artemzharkov10_gold.gold_realtime_road_hazard")
df_silver =  spark.table("dbr_dev.artemzharkov10_silver.silver_streaming_weather")
df_bronze = spark.table("dbr_dev.artemzharkov10_bronze.bronze_streaming_weather")

# %%
display(df)
# display(df_silver)
# display(df_bronze)
